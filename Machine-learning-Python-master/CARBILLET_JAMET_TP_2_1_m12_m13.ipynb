# %% [markdown]
# # TP 2.1 - Minor Assignments 12 & 13

# %%
# %matplotlib notebook

# %% [markdown]
# <div class="alert alert-danger">
#   <b>Minor Assignment 12/13:</b> <br/>
#   Using the iris dataset used above, figure out how to apply FastICA in the same manner as PCA, plot the output on the first two components. How does it fare compared with PCA? <br/>
# FastICA documentation: <a href="https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.FastICA.html">https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.FastICA.html</a><br/>
#     Same question for CCA (<a href="https://scikit-learn.org/stable/modules/cross_decomposition.html">https://scikit-learn.org/stable/modules/cross_decomposition.html</a>)
# </div>

# %%
# ESTHER JAMET & ALEXIS CARBILLET
# Assignment 12

# import des bibliothèques
from sklearn.datasets import load_iris
from sklearn.decomposition import FastICA
import matplotlib.pyplot as plt

# import des données
iris = load_iris()
X = iris.data
y = iris.target

# FastICA
ica = FastICA(n_components=2, whiten=True)
ica.fit(X)

X_ica = ica.transform(X)

# Visualisation
target_ids = range(len(iris.target_names))
plt.figure()
for i, c, label in zip(target_ids, 'rgbcmykw', iris.target_names):
    plt.scatter(X_ica[y == i, 0], X_ica[y == i, 1], c=c, label=label)
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# On obtient une sortie de ICA très proche de celle obtenue en TP par PCA.

# %%
# ESTHER JAMET & ALEXIS CARBILLET
# Assignment 12

# import des bibliothèques
from sklearn.datasets import load_iris
from sklearn.cross_decomposition import CCA
import matplotlib.pyplot as plt

# import des données
iris = load_iris()
X = iris.data
y = iris.target

# CCA
cca = CCA(n_components=2, scale=True)
cca.fit(X, y)

X_cca = cca.transform(X)

# Visualisation
target_ids = range(len(iris.target_names))
plt.figure()
for i, c, label in zip(target_ids, 'rgbcmykw', iris.target_names):
    plt.scatter(X_cca[y == i, 0], X_cca[y == i, 1], c=c, label=label)
plt.legend()
# Out:
# C:\Users\jamet\Anaconda3\lib\site-packages\sklearn\cross_decomposition\pls_.py:291: UserWarning: Y residual constant at iteration 1
#   warnings.warn('Y residual constant at iteration %s' % k)
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Pour CCA, la réduction de dimensionnalité a un autre aspect car les données sont projetées sur 1 dimension.
# Cependant, on a toujours 3 clusters, qui ressemblent à ceux obtenus par PCA et ICA.

# %% [markdown]
# <div class="alert alert-danger">
#   <b>Minor Assignment 13/13:</b> <br/>
# Apply PCA, FastICA, as well as all manifold learning techniques available in scikit-learn (<a href="https://scikit-learn.org/stable/modules/manifold.html">https://scikit-learn.org/stable/modules/manifold.html</a>) to project the data to two dimensions.
# Which visualization technique separates the classes most cleanly?
# </div>

# %%
# ESTHER JAMET & ALEXIS CARBILLET
# Assignment 13

# import des bibliothèques
from sklearn.datasets import make_swiss_roll
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

# import des données
X, color = make_swiss_roll(n_samples=4000, noise=0.2)

# Visualisation des données à projeter
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=color, cmap=plt.cm.Spectral)
ax.set_title("Original data")
ax.view_init(30,100)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# ESTHER JAMET & ALEXIS CARBILLET
# Assignment 13

# import des bibliothèques
from sklearn.datasets import make_swiss_roll
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# import des données
X, y = make_swiss_roll(n_samples=4000, noise=0.2)

# PCA
X_pca = PCA(n_components=2).fit_transform(X)
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# ESTHER JAMET & ALEXIS CARBILLET
# Assignment 13

# import des bibliothèques
from sklearn.datasets import make_swiss_roll
from sklearn.decomposition import FastICA
import matplotlib.pyplot as plt

# import des données
X, y = make_swiss_roll(n_samples=4000, noise=0.2)

# FastICA
X_ica = FastICA(n_components=2).fit_transform(X)
plt.scatter(X_ica[:, 0], X_ica[:, 1], c=y)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# ESTHER JAMET & ALEXIS CARBILLET
# Assignment 13

# import des bibliothèques
from sklearn.datasets import make_swiss_roll
from sklearn.manifold import LocallyLinearEmbedding, Isomap
import matplotlib.pyplot as plt

# import des données
X, y = make_swiss_roll(n_samples=4000, noise=0.2)

# Manifold learning technique
lle = LocallyLinearEmbedding(n_neighbors=15, n_components=2, method='modified')
X_lle = lle.fit_transform(X)
plt.scatter(X_lle[:, 0], X_lle[:, 1], c=y);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# En visualisant les projections, nous trouvons que la technique de visualisation séparant le mieux les classes dans ce cas est la méthode PCA.
